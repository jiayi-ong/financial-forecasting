# %%
import pandas as pd

# %%
# load data
num_df = pd.read_csv("./Data/SEC Statements 2023q1/num.txt", delimiter="\t")
sub_df = pd.read_csv("./Data/SEC Statements 2023q1/sub.txt", delimiter="\t")

# format dates
num_df["ddate"] = pd.to_datetime(num_df["ddate"], format="%Y%m%d")
num_df["year"] = num_df["ddate"].dt.year

# %% [markdown]
# ## Explore One Entity

# %%
# TESLA has 3 unique adsh, each differing by the columns shown
view = sub_df[sub_df.name.str.contains("TESLA")].T
select = view.apply(lambda x: x.nunique() > 1, axis=1)
view[select]
# Out:
#                           20470                     22013  \
# adsh       0000950170-23-001409      0001564590-23-000799
# wksi                          1                         0
# form                       10-K                       8-K
# period               20221231.0                20230131.0
# filed                  20230131                  20230125
# accepted  2023-01-30 21:29:00.0     2023-01-25 16:41:00.0
# detail                        1                         0
# instance  tsla-20221231_htm.xml  tsla-8k_20230120_htm.xml
#
#                              25901
# adsh          0001564590-23-000002
# wksi                             0
# form                           8-K
# period                  20221231.0
# filed                     20230103
# accepted     2023-01-03 06:09:00.0
# detail                           0
# instance  tsla-8k_20230102_htm.xml

# %%
view
# Out:
#                             20470                     22013  \
# adsh         0000950170-23-001409      0001564590-23-000799
# cik                       1318605                   1318605
# name                  TESLA, INC.               TESLA, INC.
# sic                        3711.0                    3711.0
# countryba                      US                        US
# stprba                         CA                        CA
# cityba                  PALO ALTO                 PALO ALTO
# zipba                       94304                     94304
# bas1           3500 DEER CREEK RD        3500 DEER CREEK RD
# bas2                          NaN                       NaN
# baph                 650-681-5000              650-681-5000
# countryma                      US                        US
# stprma                         CA                        CA
# cityma                  PALO ALTO                 PALO ALTO
# zipma                       94304                     94304
# mas1           3500 DEER CREEK RD        3500 DEER CREEK RD
# mas2                          NaN                       NaN
# countryinc                     US                        US
# stprinc                        DE                        DE
# ein                     912197729                 912197729
# former           TESLA MOTORS INC          TESLA MOTORS INC
# changed                20050222.0                20050222.0
# afs                         1-LAF                     1-LAF
# wksi                            1                         0
# fye                        1231.0                    1231.0
# form                         10-K                       8-K
# period                 20221231.0                20230131.0
# fy                         2022.0                       NaN
# fp                             FY                       NaN
# filed                    20230131                  20230125
# accepted    2023-01-30 21:29:00.0     2023-01-25 16:41:00.0
# prevrpt                         0                         0
# detail                          1                         0
# instance    tsla-20221231_htm.xml  tsla-8k_20230120_htm.xml
# nciks                           1                         1
# aciks                         NaN                       NaN
#
#                                25901
# adsh            0001564590-23-000002
# cik                          1318605
# name                     TESLA, INC.
# sic                           3711.0
# countryba                         US
# stprba                            CA
# cityba                     PALO ALTO
# zipba                          94304
# bas1              3500 DEER CREEK RD
# bas2                             NaN
# baph                    650-681-5000
# countryma                         US
# stprma                            CA
# cityma                     PALO ALTO
# zipma                          94304
# mas1              3500 DEER CREEK RD
# mas2                             NaN
# countryinc                        US
# stprinc                           DE
# ein                        912197729
# former              TESLA MOTORS INC
# changed                   20050222.0
# afs                            1-LAF
# wksi                               0
# fye                           1231.0
# form                             8-K
# period                    20221231.0
# fy                               NaN
# fp                               NaN
# filed                       20230103
# accepted       2023-01-03 06:09:00.0
# prevrpt                            0
# detail                             0
# instance    tsla-8k_20230102_htm.xml
# nciks                              1
# aciks                            NaN

# %%
# filter for the adsh corresponding to 10-K filing
adsh = "0000950170-23-001409"
counts = num_df.query("adsh == @adsh & ddate == '2022-12-31'").value_counts("tag")
counts
# Out:
# tag
# AccountsAndNotesReceivableNet                                     1
# NetIncomeLossAvailableToCommonStockholdersDiluted                 1
# NumberOfCustomersRepresentAccountReceivableThresholdPercentage    1
# NotesReceivableNet                                                1
# NotesAndLoansReceivableNetCurrent                                 1
#                                                                  ..
# FinanceLeaseInterestPaymentOnLiability                            1
# FinanceLeaseInterestExpense                                       1
# FinanceLeaseExpense                                               1
# FairValueNetAssetLiability                                        1
# WeightedAverageNumberOfSharesOutstandingBasic                     1
# Length: 319, dtype: int64

# %%
view = (num_df
 .query("adsh == @adsh")
 .sort_values("tag")
 .groupby("tag")
 .tail(1)
 .pivot(values="value", columns=["tag"], index=["adsh"])
 .T)

for row in view.iterrows():
    print(row[0], row[1][0])
# Out:
# AccountsAndNotesReceivableNet 280000000.0
# AccountsPayableCurrent 15255000000.0
# AccountsReceivableNetCurrent 1913000000.0
# AccountsReceivableThresholdPercentage 0.1
# AccruedAndOtherCurrentLiabilities 7142000000.0
# AccruedPurchases 2747000000.0
# AccruedWarrantyReserveCurrentPortion 703000000.0
# AccruedWarrantyReserveNoncurrent 1398000000.0
# AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment 9041000000.0
# AccumulatedOtherComprehensiveIncomeLossNetOfTax 54000000.0
# AdditionalPaidInCapital 27260000000.0
# AdditionalPaidInCapitalCommonStock 29803000000.0
# AdjustmentsToAdditionalPaidInCapitalSharebasedCompensationRequisiteServicePeriodRecognitionValue 1806000000.0
# AllocatedShareBasedCompensationExpense 1734000000.0
# Assets 62131000000.0
# AssetsCurrent 27100000000.0
# AvailableForSaleDebtSecuritiesGrossUnrealizedGain 1000000.0
# AvailableForSaleDebtSecuritiesGrossUnrealizedLoss 1000000.0
# AvailableForSaleOfSecuritiesAmortizedCost 22209000000.0
# AvailableForSaleSecuritiesDebtMaturitiesNextRollingTwelveMonthsAmortizedCostBasis 5135000000.0
# AvailableForSaleSecuritiesDebtMaturitiesRollingYearSixThroughTenAmortizedCostBasis 161000000.0
# AvailableForSaleSecuritiesDebtMaturitiesRollingYearTwoThroughFiveAmortizedCostBasis 636000000.0
# AvailableForSaleSecuritiesDebtMaturitiesSingleMaturityDateAmortizedCostBasis 5932000000.0
# AvailableForSaleSecuritiesDebtSecurities 22185000000.0
# BusinessExitCosts1 36000000.0
# BuyOutOfNoncontrollingInterest -27000000.0
# CashAndCashEquivalentsAtCarryingValue 17576000000.0
# CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsIncludingDisposalGroupAndDiscontinuedOperations 6783000000.0
# CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect -1220000000.0
# CommitmentsAndContingencies nan
# CommonStockParOrStatedValuePerShare 0.001
# CommonStockPublicOfferingIssuanceCosts 68000000.0
# CommonStockSharesAuthorized 6000000000.0
# CommonStockSharesIssued 3100000000.0
# CommonStockSharesOutstanding 3164000000.0
# CommonStockValue 3000000.0
# ComprehensiveIncomeNetOfTax 12141000000.0
# ComprehensiveIncomeNetOfTaxAttributableToNoncontrollingInterest 31000000.0
# ComprehensiveIncomeNetOfTaxIncludingPortionAttributableToNoncontrollingInterest 12172000000.0
# ContractWithCustomerAssetAndLiabilityRevenueRecognizedInNextRollingTwelveMonths 639000000.0
# ContractWithCustomerLiability 2382000000.0
# ContractWithCustomerLiabilityAdditions 1178000000.0
# ContractWithCustomerLiabilityCurrent 1447000000.0
# ContractWithCustomerLiabilityIncreaseDecrease -67000000.0
# ContractWithCustomerLiabilityNoncurrent 2052000000.0
# ContractWithCustomerLiabilityRevenueRecognized -366000000.0
# ContractWithCustomerLiabilityRevenueRecognizedOutOfPriorPeriodBalance 472000000.0
# CostOfGoodsSoldSalesTypeLease 427000000.0
# CostOfRevenue 60609000000.0
# CumulativeImpairmentOfIntangibleAssetsExcludingGoodwill 204000000.0
# CurrentFederalTaxExpenseBenefit 0.0
# CurrentForeignTaxExpenseBenefit 248000000.0
# CurrentIncomeTaxExpenseBenefit 252000000.0
# CurrentStateAndLocalTaxExpenseBenefit 4000000.0
# CustomerDepositsLiabilitiesCurrent 925000000.0
# DebtCurrent 1088000000.0
# DebtInstrumentCarryingAmount 2061000000.0
# DebtInstrumentUnusedBorrowingCapacityAmount 1108000000.0
# DeferredFederalIncomeTaxExpenseBenefit 0.0
# DeferredForeignIncomeTaxExpenseBenefit 40000000.0
# DeferredIncomeTaxExpenseBenefit 40000000.0
# DeferredIncomeTaxLiabilities 1941000000.0
# DeferredStateAndLocalIncomeTaxExpenseBenefit 1000000.0
# DeferredTaxAndOtherLiabilitiesNoncurrent 24000000.0
# DeferredTaxAssetLiabilitiesNet 247000000.0
# DeferredTaxAssetsCapitalizedResearchAndDevelopmentCosts 0.0
# DeferredTaxAssetsDeferredGlobalIntangibleLowTaxedIncomeTaxAssets 556000000.0
# DeferredTaxAssetsDeferredIncome 751000000.0
# DeferredTaxAssetsGross 9533000000.0
# DeferredTaxAssetsInventory 819000000.0
# DeferredTaxAssetsNet 2006000000.0
# DeferredTaxAssetsOperatingLeaseRightOfUseLiabilities 554000000.0
# DeferredTaxAssetsOperatingLossCarryforwards 7607000000.0
# DeferredTaxAssetsOperatingLossCarryforwardsDomestic 13570000000.0
# DeferredTaxAssetsTaxCreditCarryforwardsOther 335000000.0
# DeferredTaxAssetsTaxCreditCarryforwardsResearch 923000000.0
# DeferredTaxAssetsTaxDeferredExpenseCompensationAndBenefitsShareBasedCompensationCost 115000000.0
# DeferredTaxAssetsTaxDeferredExpenseReservesAndAccrualsOther 178000000.0
# DeferredTaxAssetsValuationAllowance 9074000000.0
# DeferredTaxLiabilitiesInvestments 209000000.0
# DeferredTaxLiabilitiesOperatingLeaseRightOfUseAssets 506000000.0
# DeferredTaxLiabilitiesOther 13000000.0
# DeferredTaxLiabilitiesPropertyPlantAndEquipment 1178000000.0
# DeferredTaxLiabilitiesTaxDeferredIncome 49000000.0
# DeferredTaxLiabilitiesUndistributedForeignEarnings 0.0
# DeferredTaxLiabilityNotRecognizedAmountOfUnrecognizedDeferredTaxLiabilityUndistributedEarningsOfForeignSubsidiaries 168000000.0
# DefinedContributionPlanEmployerDiscretionaryContributionAmount 91000000.0
# DefinedContributionPlanEmployerMatchingContributionPercentOfMatch 0.5
# DefinedContributionPlanMaximumAnnualContributionsPerEmployeeAmount 3000.0
# Depreciation 2420000000.0
# DepreciationAmortizationAndImpairment 2322000000.0
# DigitalAssetsNetNonCurrent 184000000.0
# DigitalAssetsPurchaseCurrencyConversionRate 0.75
# DilutiveSecuritiesEffectOnBasicEarningsPerShareOther 1000000.0
# EarningsPerShareBasic 1.87
# EarningsPerShareDiluted 0.21
# EffectOfExchangeRateOnCashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsIncludingDisposalGroupAndDiscontinuedOperations -183000000.0
# Effectiveincometaxratereconciliationglobalintangiblelowtaxedincomeinclusion 1279000000.0
# Effectiveincometaxratereconciliationunrecognizedtaxbenefits 252000000.0
# EmployeeRelatedLiabilitiesCurrent 1026000000.0
# EmployeeServiceShareBasedCompensationAllocationOfRecognizedPeriodCostsCapitalizedAmount 89000000.0
# EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized 3940000000.0
# EmployeeServiceShareBasedCompensationTaxBenefitFromCompensationExpense -745000000.0
# EntityCommonStockSharesOutstanding 3164102701.0
# EntityPublicFloat 580480000000.0
# ExtinguishmentOfDebtAmount 24000000.0
# FairMarketValueOfIntangibleAssets 1990000000.0
# FairValueNetAssetLiability 9710000000.0
# FinanceLeaseExpense 504000000.0
# FinanceLeaseInterestExpense 89000000.0
# FinanceLeaseInterestPaymentOnLiability 100000000.0
# FinanceLeaseLiability 1492000000.0
# FinanceLeaseLiabilityCurrent 486000000.0
# FinanceLeaseLiabilityNoncurrent 568000000.0
# FinanceLeaseLiabilityPaymentsDue 1130000000.0
# FinanceLeaseLiabilityPaymentsDueAfterYearFive 4000000.0
# FinanceLeaseLiabilityPaymentsDueNextTwelveMonths 534000000.0
# FinanceLeaseLiabilityPaymentsDueYearFive 31000000.0
# FinanceLeaseLiabilityPaymentsDueYearFour 52000000.0
# FinanceLeaseLiabilityPaymentsDueYearThree 122000000.0
# FinanceLeaseLiabilityPaymentsDueYearTwo 387000000.0
# FinanceLeaseLiabilityUndiscountedExcessAmount 76000000.0
# FinanceLeasePrincipalPayments 502000000.0
# FinanceLeaseRightOfUseAsset 1563000000.0
# FinanceLeaseRightOfUseAssetAmortization 348000000.0
# FinanceLeaseWeightedAverageDiscountRatePercent 0.058
# FinancingReceivableAllowanceForCreditLosses 41000000.0
# ForeignCurrencyTransactionGainLossRealizedAndUnrealized -114000000.0
# ForeignCurrencyTransactionGainLossUnrealized -81000000.0
# GainLossOnDigitalAssets 0.0
# GainLossOnDispositionOfIntangibleAssets 128000000.0
# GainLossOnInvestments 128000000.0
# Goodwill 194000000.0
# GoodwillImpairedAccumulatedImpairmentLoss 0.0
# GoodwillImpairmentLoss 0.0
# GoodwillPeriodIncreaseDecrease 6000000.0
# GovernmentGrantReceipt 123000000.0
# GrantFundingAmountReceived 6000000.0
# GrossProfit 6630000000.0
# ImpairmentOfIntangibleAssetsExcludingGoodwill 204000000.0
# ImpairmentOfIntangibleAssetsIndefinitelivedExcludingGoodwill 101000000.0
# IncomeLossFromContinuingOperationsBeforeIncomeTaxesAttributableToNoncontrollingInterestAndRedeemableNoncontrollingInterest 141000000.0
# IncomeLossFromContinuingOperationsBeforeIncomeTaxesDomestic 5524000000.0
# IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest 1154000000.0
# IncomeLossFromContinuingOperationsBeforeIncomeTaxesForeign 6348000000.0
# IncomeTaxExpenseBenefit 292000000.0
# IncomeTaxReconciliationChangeInDeferredTaxAssetsValuationAllowance -1532000000.0
# IncomeTaxReconciliationForeignIncomeTaxRateDifferential -923000000.0
# IncomeTaxReconciliationIncomeTaxExpenseBenefitAtFederalStatutoryIncomeTaxRate 2881000000.0
# IncomeTaxReconciliationMinorityInterestIncomeExpense 42000000.0
# IncomeTaxReconciliationNondeductibleExpenseOther 52000000.0
# IncomeTaxReconciliationNondeductibleExpenseShareBasedCompensationCost 184000000.0
# IncomeTaxReconciliationStateAndLocalIncomeTaxes 51000000.0
# IncomeTaxReconciliationTaxCredits 181000000.0
# IncomeTaxesPaid 1203000000.0
# IncreaseDecreaseInAccountsPayableAndAccruedLiabilities 2102000000.0
# IncreaseDecreaseInAccountsReceivable 652000000.0
# IncreaseDecreaseInContractWithCustomerLiability 321000000.0
# IncreaseDecreaseInContractWithCustomerLiabilityCustomerDeposits 186000000.0
# IncreaseDecreaseInInventories 6465000000.0
# IncreaseDecreaseInOperatingLeaseVehicles 1570000000.0
# IncreaseDecreaseInOtherNoncurrentAssets 344000000.0
# IncreaseDecreaseInOtherNoncurrentLiabilities 495000000.0
# IncreaseDecreaseInPrepaidDeferredExpenseAndOtherAssets 1417000000.0
# IncrementalCommonSharesAttributableToCallOptionsAndWarrants 32000000.0
# IncrementalCommonSharesAttributableToConversionOfDebtSecurities 3000000.0
# IncrementalCommonSharesAttributableToShareBasedPaymentArrangements 310000000.0
# IntangibleAssetsNetExcludingGoodwill 257000000.0
# InterestCostsCapitalized 48000000.0
# InterestExpense 748000000.0
# InterestPaidNet 444000000.0
# InventoryFinishedGoodsNetOfReserves 1277000000.0
# InventoryNet 12839000000.0
# InventoryPartsAndComponentsNetOfReserves 575000000.0
# InventoryRawMaterialsNetOfReserves 6137000000.0
# InventoryWorkInProcessNetOfReserves 1089000000.0
# InventoryWriteDown 202000000.0
# InvestmentIncomeInterest 56000000.0
# LeaseCost 899000000.0
# LesseeOperatingLeaseLiabilityPaymentsDue 3146000000.0
# LesseeOperatingLeaseLiabilityPaymentsDueAfterYearFive 805000000.0
# LesseeOperatingLeaseLiabilityPaymentsDueNextTwelveMonths 610000000.0
# LesseeOperatingLeaseLiabilityPaymentsDueYearFive 300000000.0
# LesseeOperatingLeaseLiabilityPaymentsDueYearFour 383000000.0
# LesseeOperatingLeaseLiabilityPaymentsDueYearThree 490000000.0
# LesseeOperatingLeaseLiabilityPaymentsDueYearTwo 558000000.0
# LesseeOperatingLeaseLiabilityUndiscountedExcessAmount 497000000.0
# LessorOperatingLeasePaymentsToBeReceived 4681000000.0
# LessorOperatingLeasePaymentsToBeReceivedFiveYears 194000000.0
# LessorOperatingLeasePaymentsToBeReceivedFourYears 215000000.0
# LessorOperatingLeasePaymentsToBeReceivedNextTwelveMonths 1212000000.0
# LessorOperatingLeasePaymentsToBeReceivedThereafter 1697000000.0
# LessorOperatingLeasePaymentsToBeReceivedThreeYears 463000000.0
# LessorOperatingLeasePaymentsToBeReceivedTwoYears 900000000.0
# LettersOfCreditOutstandingAmount 318000000.0
# Liabilities 36440000000.0
# LiabilitiesAndStockholdersEquity 82338000000.0
# LiabilitiesCurrent 19705000000.0
# LongTermDebt 1029000000.0
# LongTermDebtAndFinanceLeasesCurrent 1589000000.0
# LongTermDebtAndFinanceLeasesNoncurrent 1597000000.0
# LongTermDebtMaturitiesRepaymentsOfPrincipalAfterYearFive 257000000.0
# LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths 1020000000.0
# LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFive 25000000.0
# LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFour 35000000.0
# LongTermDebtMaturitiesRepaymentsOfPrincipalInYearThree 39000000.0
# LongTermDebtMaturitiesRepaymentsOfPrincipalInYearTwo 685000000.0
# LossContingencyDamagesAwardedValue 15000000.0
# LossContingencyDamagesSoughtValue 136900000.0
# LossContingencyNumberOfPlaintiffs 2.0
# LossContingencyNumberOfPurportedStockholderClassActionsFiled 9.0
# MinimumTaxRate 0.15
# MinorityInterest 826000000.0
# MinorityInterestDecreaseFromDistributionsToNoncontrollingInterestHolders 113000000.0
# MinorityInterestDecreaseFromRedemptions 5000000.0
# NetCashProvidedByUsedInFinancingActivities -3527000000.0
# NetCashProvidedByUsedInInvestingActivities -11973000000.0
# NetCashProvidedByUsedInOperatingActivities 5943000000.0
# NetIncomeLoss 5519000000.0
# NetIncomeLossAttributableToNoncontrollingInterest 31000000.0
# NetIncomeLossAvailableToCommonStockholdersBasic 12583000000.0
# NetIncomeLossAvailableToCommonStockholdersDiluted 5533000000.0
# NetIncomeLossIncludingPortionAttributableToRedeemableNonControllingInterestAndNonControllingInterestInSubsidiaries 5601000000.0
# NoncashInterestIncomeExpenseAndOtherOperatingActivities -340000000.0
# NoncashOrPartNoncashAcquisitionValueOfAssetsAcquired1 2251000000.0
# NoncontrollingInterestsIncreaseFromContributionsFromNoncontrollingInterests 17000000.0
# NoncurrentAssets 24649000000.0
# NotesAndLoansReceivableNetCurrent 11000000.0
# NotesReceivableNet 128000000.0
# NumberOfConsolidatedActions 5.0
# NumberOfCustomersRepresentAccountReceivableThresholdPercentage 0.0
# NumberOfOperatingSegments 2.0
# NumberOfOperationalMilestonesAchieved 3.0
# NumberOfPendingResolutions 7.0
# NumberOfReportableSegments 2.0
# NumberOfTeslaStockholders 2.0
# NumberOfTransactions 6.0
# OperatingExpenses 7197000000.0
# OperatingIncomeLoss 1994000000.0
# OperatingLeaseExpense 451000000.0
# OperatingLeaseLiability 2039000000.0
# OperatingLeaseLiabilityCurrent 485000000.0
# OperatingLeaseLiabilityNoncurrent 1671000000.0
# OperatingLeasePayments 616000000.0
# OperatingLeaseRightOfUseAsset 2016000000.0
# OperatingLeaseWeightedAverageDiscountRatePercent 0.05
# OperatingLeasesNotYetCommencedValueWithAggregateRentPayments 901000000.0
# OtherAssetsNoncurrent 4193000000.0
# OtherComprehensiveIncomeLossForeignCurrencyTransactionAndTranslationAdjustmentNetOfTax -308000000.0
# OtherComprehensiveIncomeLossNetOfTaxPortionAttributableToParent -415000000.0
# OtherLiabilitiesCurrent 310000000.0
# OtherLiabilitiesMiscellaneousNoncurrent 320000000.0
# OtherLiabilitiesNoncurrent 3546000000.0
# OtherNonoperatingIncomeExpense 135000000.0
# PaymentsForBuyOutsOfNoncontrollingInterestsInSubsidiaries 10000000.0
# PaymentsForSolarEnergySystemsNetOfSales 5000000.0
# PaymentsOfDebtIssuanceCosts 6000000.0
# PaymentsToAcquireBusinessesNetOfCashAcquired 0.0
# PaymentsToAcquireIntangibleAssets 1500000000.0
# PaymentsToAcquireInvestments 5835000000.0
# PaymentsToAcquireOtherIndefiniteLivedIntangibleAssets 9000000.0
# PaymentsToAcquirePropertyPlantAndEquipment 6482000000.0
# PaymentsToMinorityShareholders 157000000.0
# PercentageOfEmployeesEligibleCompensationVested 0.06
# PercentageOfPayrollDeductionsOfEmployeesEligibleCompensation 0.15
# PreferredStockParOrStatedValuePerShare 0.001
# PreferredStockSharesAuthorized 100000000.0
# PreferredStockSharesIssued 0.0
# PreferredStockSharesOutstanding 0.0
# PreferredStockValue 0.0
# PrepaidExpenseAndOtherAssetsCurrent 1723000000.0
# ProceedsFromIssuanceOfCommonStock 0.0
# ProceedsFromIssuanceOfDebt 8883000000.0
# ProceedsFromIssuanceOfSharesUnderIncentiveAndShareBasedCompensationPlansIncludingStockOptions 417000000.0
# ProceedsFromMinorityShareholders 0.0
# ProceedsFromRepaymentsOfSecuredDebt -9000000.0
# ProceedsFromSaleMaturityAndCollectionsOfInvestments 22000000.0
# ProceedsFromSalesOfDigitalAssets 272000000.0
# ProductWarrantyAccrualPreexistingIncreaseDecrease 522000000.0
# ProfitLoss 5644000000.0
# ProfitsFromIncomeOfCorporations 1000000000.0
# PropertyPlantAndEquipmentGross 32589000000.0
# PropertyPlantAndEquipmentNet 23548000000.0
# PropertySubjectToOrAvailableForOperatingLeaseAccumulatedDepreciation 773000000.0
# PropertySubjectToOrAvailableForOperatingLeaseGross 5280000000.0
# PurchaseOfDigitalAssets 0.0
# ReclassificationsOfPermanentEquityToTemporaryEquity 51000000.0
# RedeemableNoncontrollingInterestEquityCarryingAmount 568000000.0
# RepaymentsOfConvertibleAndOtherDebt 11623000000.0
# ResearchAndDevelopmentExpense 1491000000.0
# RestrictedCashCurrent 294000000.0
# RestrictedCashNoncurrent 377000000.0
# RestructuringAndOtherExpenses 176000000.0
# RetainedEarningsAccumulatedDeficit -5399000000.0
# RevenueDueToChangesInRegulation 288000000.0
# Revenues 53823000000.0
# RightOfUseAssetObtainedInExchangeForFinanceLeaseLiability 188000000.0
# RightOfUseAssetObtainedInExchangeForOperatingLeaseLiability 553000000.0
# SalesReturnReserveCurrent 265000000.0
# SalesReturnReserveFromBuybackOptions 91000000.0
# SalesReturnReserveFromShortTermBuyBackOptions 40000000.0
# SalesReturnReserveNoncurrent 51000000.0
# SalesTypeAndDirectFinancingLeasesLeaseReceivablePaymentsToBeReceived 837000000.0
# SalesTypeAndDirectFinancingLeasesLeaseReceivablePaymentsToBeReceivedFiveYears 49000000.0
# SalesTypeAndDirectFinancingLeasesLeaseReceivablePaymentsToBeReceivedFourYears 174000000.0
# SalesTypeAndDirectFinancingLeasesLeaseReceivablePaymentsToBeReceivedNextTwelveMonths 202000000.0
# SalesTypeAndDirectFinancingLeasesLeaseReceivablePaymentsToBeReceivedThereafter 12000000.0
# SalesTypeAndDirectFinancingLeasesLeaseReceivablePaymentsToBeReceivedThreeYears 192000000.0
# SalesTypeAndDirectFinancingLeasesLeaseReceivablePaymentsToBeReceivedTwoYears 208000000.0
# SalesTypeLeaseLeaseReceivable 837000000.0
# SalesTypeLeaseNetInvestmentInLeaseAfterAllowanceForCreditLoss 376000000.0
# SalesTypeLeaseNetInvestmentInLeaseAllowanceForCreditLoss 1000000.0
# SalesTypeLeaseRevenue 120000000.0
# SalesTypeLeaseUnearnedInterestIncome 95000000.0
# SellingGeneralAndAdministrativeExpense 3145000000.0
# ShareBasedCompensation 2121000000.0
# ShareBasedCompensationArrangementByShareBasedPaymentAwardDiscountFromMarketPriceOfferingDate 0.85
# ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsExercisesInPeriodTotalIntrinsicValue 1550000000.0
# ShortTermInvestments 131000000.0
# StandardProductWarrantyAccrual 2101000000.0
# StandardProductWarrantyAccrualPayments 312000000.0
# StandardProductWarrantyAccrualWarrantiesIssued 1685000000.0
# StockIssuedDuringPeriodSharesEmployeeStockPurchasePlans 1400000.0
# StockIssuedDuringPeriodValueConversionOfConvertibleSecurities 6000000.0
# StockIssuedDuringPeriodValueEquityIncentiveAwards 541000000.0
# StockIssuedDuringPeriodValueNewIssues 12269000000.0
# StockholdersEquity 30189000000.0
# StockholdersEquityIncludingPortionAttributableToNoncontrollingInterest 45489000000.0
# StockholdersEquityNoteStockSplitConversionRatio1 3.0
# TaxesPayableCurrent 1122000000.0
# TemporaryEquityCarryingAmountAttributableToParent 51000000.0
# UnrealizedGainLossOnInvestments 0.0
# UnrecognizedTaxBenefits 531000000.0
# UnrecognizedTaxBenefitsDecreasesResultingFromPriorPeriodTaxPositions 12000000.0
# UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestAccrued 31000000.0
# UnrecognizedTaxBenefitsIncreasesResultingFromCurrentPeriodTaxPositions 222000000.0
# UnrecognizedTaxBenefitsIncreasesResultingFromPriorPeriodTaxPositions 66000000.0
# UnrecognizedTaxBenefitsOfDeferredTaxAccountingThatWouldNotImpactAnnualEffectiveRate 572000000.0
# UnrecognizedTaxBenefitsReductionsResultingFromLapseOfApplicableStatuteOfLimitations 7000000.0
# WeightedAverageNumberOfDilutedSharesOutstanding 3249000000.0
# WeightedAverageNumberOfSharesOutstandingBasic 2959000000.0

# %% [markdown]
# ## Explore All Entities

# %%
# get entity names that have filed one 10-K form
entity_names = sub_df.query("form == '10-K'").value_counts("name")
entity_names = entity_names[entity_names == 1].index

# get the corresponding Accession Numbers (id assigned to each EDGAR submission)
adsh_list = sub_df[sub_df.name.isin(entity_names)].adsh
print(len(adsh_list))
# Out:
# 19545

# %%
# making sure all tags (or most) occurs once
queries = ["adsh in @adsh_list",
           "coreg.isnull()"
          ]
tag_counts = num_df.query(" & ".join(queries)).value_counts(["adsh", "tag"]).sort_values(ascending=False)
tag_counts[tag_counts > 1]
# Out:
# adsh                  tag
# 0001580345-23-000008  EarningsPerShareBasicDistributed                        42
# 0000726728-23-000044  CommonStockDividendsPerShareCashPaid                    39
# 0001577134-23-000008  StockIssuedDuringPeriodValueDividendReinvestmentPlan    23
#                       PaymentsOfDividendsCommonStock                          23
#                       PaymentsOfDividends                                     23
#                                                                               ..
# 0001477932-23-000591  AllowanceForDoubtfulAccountsReceivable                   2
#                       CashAndCashEquivalentsAtCarryingValue                    2
# 0001477932-23-000586  WeightedAverageNumberOfShareOutstandingBasic             2
# 0001628280-23-009556  OperatingLeaseRightOfUseAssetAmortizationExpense         2
# 0001477932-23-000586  WeightedAverageNumberOfDilutedShareOutstanding           2
# Length: 888626, dtype: int64

# %%
data = (num_df
        .query(" & ".join(queries))
        .sort_values("ddate")
        .groupby(["adsh", "tag"])
        .tail(1)
        .pivot(index=["adsh"], columns=["tag"], values="value"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 5
#       1 data = (num_df
#       2         .query(" & ".join(queries))
#       3         .sort_values("ddate")
#       4         .groupby(["adsh", "tag"])
# ----> 5         .tail(1)
#       6         .pivot(index=["adsh"], columns=["tag"], values="value")
#       7         .T)
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:4087, in GroupBy.tail(self, n)
#    4085 self._reset_group_selection()
#    4086 if n:
# -> 4087     mask = self._make_mask_from_positional_indexer(slice(-n, None))
#    4088 else:
#    4089     mask = self._make_mask_from_positional_indexer([])
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\indexing.py:132, in GroupByIndexingMixin._make_mask_from_positional_indexer(self, arg)
#     129         mask = self._make_mask_from_tuple(cast(tuple, arg))
#     131 elif isinstance(arg, slice):
# --> 132     mask = self._make_mask_from_slice(arg)
#     133 elif is_integer(arg):
#     134     mask = self._make_mask_from_int(cast(int, arg))
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\indexing.py:209, in GroupByIndexingMixin._make_mask_from_slice(self, arg)
#     206         mask &= (self._ascending_count - start) % step == 0
#     208 else:
# --> 209     mask &= self._descending_count < -start
#     211     offset_array = self._descending_count + start + 1
#     212     limit_array = (
#     213         self._ascending_count + self._descending_count + (start + 1)
#     214     ) < 0
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\indexing.py:243, in GroupByIndexingMixin._descending_count(self)
#     240 else:
#     241     groupby_self = self
# --> 243 return groupby_self._cumcount_array(ascending=False)
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1934, in GroupBy._cumcount_array(self, ascending)
#    1921 @final
#    1922 def _cumcount_array(self, ascending: bool = True) -> np.ndarray:
#    1923     """
#    1924     Parameters
#    1925     ----------
#    (...)
#    1932     (though the default is sort=True) for groupby in general
#    1933     """
# -> 1934     ids, _, ngroups = self.grouper.group_info
#    1935     sorter = get_group_index_sorter(ids, ngroups)
#    1936     ids, count = ids[sorter], len(ids)
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:946, in BaseGrouper.group_info(self)
#     944 @cache_readonly
#     945 def group_info(self) -> tuple[npt.NDArray[np.intp], npt.NDArray[np.intp], int]:
# --> 946     comp_ids, obs_group_ids = self._get_compressed_codes()
#     948     ngroups = len(obs_group_ids)
#     949     comp_ids = ensure_platform_int(comp_ids)
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:972, in BaseGrouper._get_compressed_codes(self)
#     966 @final
#     967 def _get_compressed_codes(
#     968     self,
#     969 ) -> tuple[npt.NDArray[np.signedinteger], npt.NDArray[np.intp]]:
#     970     # The first returned ndarray may have any signed integer dtype
#     971     if len(self.groupings) > 1:
# --> 972         group_index = get_group_index(self.codes, self.shape, sort=True, xnull=True)
#     973         return compress_group_index(group_index, sort=self._sort)
#     974         # FIXME: compress_group_index's second return value is int64, not intp
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:897, in BaseGrouper.codes(self)
#     894 @final
#     895 @property
#     896 def codes(self) -> list[npt.NDArray[np.signedinteger]]:
# --> 897     return [ping.codes for ping in self.groupings]
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:897, in <listcomp>(.0)
#     894 @final
#     895 @property
#     896 def codes(self) -> list[npt.NDArray[np.signedinteger]]:
# --> 897     return [ping.codes for ping in self.groupings]
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py:621, in Grouping.codes(self)
#     617 if self._codes is not None:
#     618     # _codes is set in __init__ for MultiIndex cases
#     619     return self._codes
# --> 621 return self._codes_and_uniques[0]
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py:692, in Grouping._codes_and_uniques(self)
#     685     uniques = (
#     686         self.grouping_vector.result_index._values  # type: ignore[assignment]
#     687     )
#     688 else:
#     689     # GH35667, replace dropna=False with use_na_sentinel=False
#     690     # error: Incompatible types in assignment (expression has type "Union[
#     691     # ndarray[Any, Any], Index]", variable has type "Categorical")
# --> 692     codes, uniques = algorithms.factorize(  # type: ignore[assignment]
#     693         self.grouping_vector, sort=self._sort, use_na_sentinel=self._dropna
#     694     )
#     695 return codes, uniques
#
# File ~\anaconda3\lib\site-packages\pandas\core\algorithms.py:822, in factorize(values, sort, na_sentinel, use_na_sentinel, size_hint)
#     819             # Don't modify (potentially user-provided) array
#     820             values = np.where(null_mask, na_value, values)
# --> 822     codes, uniques = factorize_array(
#     823         values,
#     824         na_sentinel=na_sentinel_arg,
#     825         size_hint=size_hint,
#     826     )
#     828 if sort and len(uniques) > 0:
#     829     if na_sentinel is None:
#     830         # TODO: Can remove when na_sentinel=na_sentinel as in TODO above
#
# File ~\anaconda3\lib\site-packages\pandas\core\algorithms.py:578, in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     575 hash_klass, values = _get_hashtable_algo(values)
#     577 table = hash_klass(size_hint or len(values))
# --> 578 uniques, codes = table.factorize(
#     579     values,
#     580     na_sentinel=na_sentinel,
#     581     na_value=na_value,
#     582     mask=mask,
#     583     ignore_na=ignore_na,
#     584 )
#     586 # re-cast e.g. i8->dt64/td64, uint8->bool
#     587 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# KeyboardInterrupt:

# %%
data.isna().mean(axis=0).sort_values()
# Out:
# tag
# NetIncomeLoss                                                                                       0.076038
# Assets                                                                                              0.190013
# LiabilitiesAndStockholdersEquity                                                                    0.194715
# NetCashProvidedByUsedInOperatingActivities                                                          0.201524
# NetCashProvidedByUsedInFinancingActivities                                                          0.213035
#                                                                                                       ...
# AccruedInterestExpensesNonCurrent                                                                   1.000000
# DeferredIncomeTaxesReleaseOfValuationAllowance                                                      1.000000
# RetirementOfShares                                                                                  1.000000
# CurrentIncomeTaxExpensebenefit                                                                      1.000000
# SharebasedCompensationArrangementBySharebasedPaymentAwardOptionsIntrinsicValueCancelledForfeited    1.000000
# Length: 157451, dtype: float64

# %%
data.loc["0000950170-23-001409"]
# Out:
# tag
# A1031ExchangeFundsForBusinessCombinations        NaN
# A155SeniorNotesDue2026                           NaN
# A199AQualifiedBusinessIncome                     NaN
# A2.30seniornotesdue2024                          NaN
# A2.95seniornotesdue2029                          NaN
#                                                   ..
# warrantsToPurchaseSharesOfCommonStock            NaN
# weightedAverageTradingPriceOfTheOrdinaryShares   NaN
# workingCapital                                   NaN
# workingCapitalDeficit                            NaN
# workingCapitalLoans                              NaN
# Name: 0000950170-23-001409, Length: 157451, dtype: float64
