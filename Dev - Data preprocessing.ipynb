# %% [markdown]
# ## TO-DO:
#
# - variable path
# - data cleaning and imputation (series-by-series)
# - lag variables, accounting for data refresh frequency

# %%
# DONE:
# W / M / Q -> D
# M / Q - > W
# Q -> M

# %%
import os
import json
import pandas as pd
import numpy as np

# %%
with open("../Database/data_info.json", "r") as openfile:
    dct_data_info = json.load(openfile)

# %%
# set parameters
TARGET_FREQ = "D"

# %%
dct_data_info
# Out:
# {'VAPGDPAER': {'id': 'VAPGDPAER',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Arts, Entertainment, Recreation, Accommodation, and Food Services: Arts, Entertainment, and Recreation as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:40-05',
#   'popularity': 1,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPAERAF': {'id': 'VAPGDPAERAF',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Arts, Entertainment, Recreation, Accommodation, and Food Services as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:40-05',
#   'popularity': 2,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPAF': {'id': 'VAPGDPAF',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Arts, Entertainment, Recreation, Accommodation, and Food Services: Accommodation and Food Services as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:08-05',
#   'popularity': 12,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPAFH': {'id': 'VAPGDPAFH',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Agriculture, Forestry, Fishing, and Hunting as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:06-05',
#   'popularity': 15,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPAI': {'id': 'VAPGDPAI',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Gross Domestic Product as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:40-05',
#   'popularity': 5,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPAWMS': {'id': 'VAPGDPAWMS',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Professional and Business Services: Administrative and Waste Management Services as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:40-05',
#   'popularity': 1,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPC': {'id': 'VAPGDPC',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Construction as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:03-05',
#   'popularity': 38,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPES': {'id': 'VAPGDPES',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Educational Services, Health Care, and Social Assistance: Educational Services as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:40-05',
#   'popularity': 1,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPESHS': {'id': 'VAPGDPESHS',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Educational Services, Health Care, and Social Assistance as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:39-05',
#   'popularity': 1,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPFI': {'id': 'VAPGDPFI',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Finance, Insurance, Real Estate, Rental, and Leasing: Finance and Insurance as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:03-05',
#   'popularity': 37,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPFIRL': {'id': 'VAPGDPFIRL',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Finance, Insurance, Real Estate, Rental, and Leasing as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:26-05',
#   'popularity': 3,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPGPI': {'id': 'VAPGDPGPI',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Private Goods-Producing Industries as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:26-05',
#   'popularity': 1,
#   'notes': 'Consists of agriculture, forestry, fishing, and hunting; mining; construction; and manufacturing.\nValue added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPHCSA': {'id': 'VAPGDPHCSA',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Educational Services, Health Care, and Social Assistance: Health Care and Social Assistance as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:16-05',
#   'popularity': 4,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPI': {'id': 'VAPGDPI',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Information as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:26-05',
#   'popularity': 4,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPM': {'id': 'VAPGDPM',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Mining as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:06-05',
#   'popularity': 12,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPMA': {'id': 'VAPGDPMA',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Manufacturing as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:02-05',
#   'popularity': 47,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPMCE': {'id': 'VAPGDPMCE',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Professional and Business Services: Management of Companies and Enterprises as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:39-05',
#   'popularity': 1,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPMD': {'id': 'VAPGDPMD',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Manufacturing: Durable Goods as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:15-05',
#   'popularity': 2,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPMN': {'id': 'VAPGDPMN',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Manufacturing: Nondurable Goods as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:39-05',
#   'popularity': 1,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPOSEG': {'id': 'VAPGDPOSEG',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Other Services, Except Government as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:39-05',
#   'popularity': 4,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPPBS': {'id': 'VAPGDPPBS',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Professional and Business Services as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:05-05',
#   'popularity': 14,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPPI': {'id': 'VAPGDPPI',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Private Industries as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:39-05',
#   'popularity': 1,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPPST': {'id': 'VAPGDPPST',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Professional and Business Services: Professional, Scientific, and Technical Services as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:26-05',
#   'popularity': 6,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPR': {'id': 'VAPGDPR',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Retail Trade as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:05-05',
#   'popularity': 14,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPRL': {'id': 'VAPGDPRL',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Finance, Insurance, Real Estate, Rental, and Leasing: Real Estate and Rental and Leasing as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:07-05',
#   'popularity': 18,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPSPI': {'id': 'VAPGDPSPI',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Private Services-Producing Industries as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:07-05',
#   'popularity': 8,
#   'notes': 'Consists of utilities; wholesale trade; retail trade; transportation and warehousing; information; finance, insurance, real estate, rental, and leasing; professional and business services; educational services, health care, and social assistance; arts, entertainment, recreation, accommodation, and food services; and other services, except government.\nValue added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPT': {'id': 'VAPGDPT',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Transportation and Warehousing as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:05-05',
#   'popularity': 9,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPU': {'id': 'VAPGDPU',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Utilities as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:07-05',
#   'popularity': 6,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'VAPGDPW': {'id': 'VAPGDPW',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Value Added by Industry: Wholesale Trade as a Percentage of GDP',
#   'observation_start': '2005-01-01',
#   'observation_end': '2023-01-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent',
#   'units_short': '%',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-06-29 11:04:08-05',
#   'popularity': 2,
#   'notes': 'Value added represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus.',
#   'category': 'Industry'},
#  'OB000334Q': {'id': 'OB000334Q',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Real Gross Domestic Product',
#   'observation_start': '2003-01-01',
#   'observation_end': '2023-04-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent Change from Quarter One Year Ago',
#   'units_short': '% Chg. from Qtr.  1 Yr. Ago',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-09-28 07:51:11-05',
#   'popularity': 28,
#   'notes': 'BEA Account Code: OB000334',
#   'category': 'GDP/GNP'},
#  'STLENI': {'id': 'STLENI',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'St. Louis Fed Economic News Index: Real GDP Nowcast',
#   'observation_start': '2013-04-01',
#   'observation_end': '2023-07-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Percent Change at Annual Rate',
#   'units_short': '% Chg. at Annual Rate',
#   'seasonal_adjustment': 'Seasonally Adjusted Annual Rate',
#   'seasonal_adjustment_short': 'SAAR',
#   'last_updated': '2023-10-20 09:46:02-05',
#   'popularity': 63,
#   'notes': 'St. Louis Fed’s Economic News Index (ENI) uses economic content from key monthly economic data releases to forecast the growth of real GDP during that quarter. In general, the most-current observation is revised multiple times throughout the quarter. The final forecasted value (before the BEA’s release of the advance estimate of GDP) is the static, historical value for that quarter. For more information, see Grover, Sean P.; Kliesen, Kevin L.; and McCracken, Michael W. “A Macroeconomic News Index for Constructing Nowcasts of U.S. Real Gross Domestic Product Growth" (https://research.stlouisfed.org/publications/review/2016/12/05/a-macroeconomic-news-index-for-constructing-nowcasts-of-u-s-real-gross-domestic-product-growth/ )',
#   'category': 'GDP/GNP'},
#  'Y694RC1Q027SBEA': {'id': 'Y694RC1Q027SBEA',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Gross Domestic Product: Research and Development',
#   'observation_start': '1947-01-01',
#   'observation_end': '2023-04-01',
#   'frequency': 'Quarterly',
#   'frequency_short': 'QS',
#   'units': 'Billions of Dollars',
#   'units_short': 'Bil. of $',
#   'seasonal_adjustment': 'Seasonally Adjusted Annual Rate',
#   'seasonal_adjustment_short': 'SAAR',
#   'last_updated': '2023-09-28 07:51:11-05',
#   'popularity': 24,
#   'notes': 'BEA Account Code: Y694RC\n\nFor more information about this series, please see http://www.bea.gov/national/.',
#   'category': 'GDP/GNP'},
#  'WEI': {'id': 'WEI',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Weekly Economic Index (Lewis-Mertens-Stock)',
#   'observation_start': '2008-01-05',
#   'observation_end': '2023-10-14',
#   'frequency': 'Weekly, Ending Saturday',
#   'frequency_short': 'W-SAT',
#   'units': 'Index',
#   'units_short': 'Index',
#   'seasonal_adjustment': 'Not Seasonally Adjusted',
#   'seasonal_adjustment_short': 'NSA',
#   'last_updated': '2023-10-19 10:36:01-05',
#   'popularity': 65,
#   'notes': 'The WEI is an index of real economic activity using timely and relevant high-frequency data. It represents the common component of ten different daily and weekly series covering consumer behavior, the labor market, and production. The WEI is scaled to the four-quarter GDP growth rate; for example, if the WEI reads -2 percent and the current level of the WEI persists for an entire quarter, one would expect, on average, GDP that quarter to be 2 percent lower than a year previously. \r\n\r\nThe WEI is a composite of 10 weekly economic indicators: Redbook same-store sales, Rasmussen Consumer Index, new claims for unemployment insurance, continued claims for unemployment insurance, adjusted income/employment tax withholdings (from Booth Financial Consulting), railroad traffic originated (from the Association of American Railroads), the American Staffing Association Staffing Index, steel production, wholesale sales of gasoline, diesel, and jet fuel, and weekly average US electricity load (with remaining data supplied by Haver Analytics). All series are represented as year-over-year percentage changes. These series are combined into a single index of weekly economic activity.\r\n\r\nFor additional details, including an analysis of the performance of the model, see Lewis, Mertens, and Stock (2020), “U.S. Economic Activity during the Early Weeks of the SARS-Cov-2 Outbreak.” (https://www.newyorkfed.org/research/staff_reports/sr920)\r\n\r\nThis index has been developed by Daniel Lewis, an economist in the Federal Reserve Bank of New York, Karel Mertens, a senior economic policy advisor at the Federal Reserve Bank of Dallas, and James Stock, the Harold Hitchings Burbank Professor of Political Economy, Faculty of Arts and Sciences of Harvard University.\r\n\r\nThe index is not an official forecast of the Federal Reserve Bank of New York, its president, the Federal Reserve System, or the Federal Open Market Committee.',
#   'category': 'GDP/GNP'},
#  'BBKMLEIX': {'id': 'BBKMLEIX',
#   'realtime_start': '2023-10-22',
#   'realtime_end': '2023-10-22',
#   'title': 'Brave-Butters-Kelley Leading Index',
#   'observation_start': '1960-01-01',
#   'observation_end': '2023-08-01',
#   'frequency': 'Monthly',
#   'frequency_short': 'MS',
#   'units': 'Standard Deviations',
#   'units_short': 'Standard Deviations',
#   'seasonal_adjustment': 'Seasonally Adjusted',
#   'seasonal_adjustment_short': 'SA',
#   'last_updated': '2023-10-02 08:31:03-05',
#   'popularity': 32,
#   'notes': "The Brave-Butters-Kelley Indexes (BBKI) are the byproduct of research originally conducted by the Federal Reserve Bank of Chicago. Currently, the BBKI are maintained and produced by the Indiana Business Research Center at the Kelley School of Business at Indiana University. The BBK Coincident and Leading Indexes and Monthly GDP Growth for the U.S. are constructed from a collapsed dynamic factor analysis of a panel of 490 monthly measures of real economic activity and quarterly real GDP growth.\n\nThe BBK Leading Index is the leading subcomponent of the cycle measured in standard deviation units from trend real GDP growth.\n\nFor more details, see also:\nBrave, Scott A., Ross Cole, and David Kelley, 2019, A 'big data' view of the U.S. economy: Introducing the Brave-Butters-Kelley Indexes (https://www.chicagofed.org/publications/chicago-fed-letter/2019/422), Chicago Fed Letter, Federal Reserve Bank of Chicago, No. 422. Crossref, https://doi.org/10.21033/cfl-2019-422\nBrave, Scott A., R. Andrew Butters, and David Kelley, 2019, A new 'big data' index of U.S. economic activity (https://www.chicagofed.org/publications/economic-perspectives/2019/1), Economic Perspectives, Federal Reserve Bank of Chicago, Vol. 43, No. 1. Crossref, https://doi.org/10.21033/ep-2019-1",
#   'category': 'GDP/GNP'},
#  'EMHYY': {'category': 'ML',
#   'title': 'Emerging Markets High Yield Corporate Bond Index Yield',
#   'frequency_short': 'D'},
#  'AAAEY': {'category': 'ML',
#   'title': 'US AAA rated Bond Index (yield)',
#   'frequency_short': 'D'},
#  'AATRI': {'category': 'ML',
#   'title': 'US AA Rated Total Return Index',
#   'frequency_short': 'D'},
#  'BEY': {'category': 'ML',
#   'title': 'US B rated Corporate Bond Index (yield)',
#   'frequency_short': 'D'},
#  'AEY': {'category': 'ML',
#   'title': 'US Corporate Bond A rated Index (yield)',
#   'frequency_short': 'D'},
#  'BBBEY': {'category': 'ML',
#   'title': 'US BBB Bond Index (yield)',
#   'frequency_short': 'D'},
#  'REALLONGTERM': {'category': 'USTREASURY',
#   'title': 'Treasury Real Long-Term Rates',
#   'frequency_short': 'D'},
#  'REALYIELD': {'category': 'USTREASURY',
#   'title': 'Treasury Real Yield Curve Rates',
#   'frequency_short': 'D'},
#  'BILLRATES': {'category': 'USTREASURY',
#   'title': 'Treasury Bill Rates',
#   'frequency_short': 'D'},
#  'YIELD': {'category': 'USTREASURY',
#   'title': 'Treasury Yield Curve Rates',
#   'frequency_short': 'D'}}

# %% [markdown]
# # Process FRED Data:

# %%
filename = "WEI.csv"
series_id = filename[:-4]
data_freq = dct_data_info[series_id]["frequency_short"]

df = pd.read_csv(f"../Database/{filename}")
df["date"] = pd.to_datetime(df["date"], format="%Y-%m-%d")
df["realtime_start"] = pd.to_datetime(df["realtime_start"], format="%Y-%m-%d")
df["realtime_end"] = pd.to_datetime(df["realtime_end"], format="%Y-%m-%d")

first_release_date = df["realtime_start"].min()
first_data_date = df["date"].min()

# %%
# maps frequency tag to interval duration in days
dct_interval = {"Q": 90, "M": 30, "W": 7, "D": 1}
interval = dct_interval[data_freq[0]]

# if the first release date is more than 5 (threshold)
# times the interval, then regarded as retrospective
retrospective = (first_release_date - first_data_date).days > 5*interval
print(retrospective)
# Out:
# True

# %%
if retrospective:
    df_extend = df.groupby("date").head(1).copy()
    df_extend["realtime_start"] = df_extend["date"]
    df = pd.concat([df, df_extend], axis=0).sort_values(["date", "realtime_start"])

# %%
df
# Out:
#      realtime_start realtime_end       date   WEI
# 0        2008-01-05   2020-06-08 2008-01-05  1.48
# 0        2020-04-16   2020-06-08 2008-01-05  1.48
# 1        2020-06-09   2020-07-29 2008-01-05  1.41
# 2        2020-07-30   2021-07-28 2008-01-05  1.42
# 3        2021-07-29   2022-01-19 2008-01-05  1.40
# ...             ...          ...        ...   ...
# 7775     2023-10-07   2023-10-18 2023-10-07  2.14
# 7775     2023-10-12   2023-10-18 2023-10-07  2.14
# 7776     2023-10-19   2023-12-31 2023-10-07  1.99
# 7777     2023-10-14   2023-12-31 2023-10-14  2.27
# 7777     2023-10-19   2023-12-31 2023-10-14  2.27
#
# [8602 rows x 4 columns]

# %%
# delay between release of datapoint and the date of datapoint
df["release_delay"] = df["realtime_start"] - df["date"]
# filter release delay
df = df[df["release_delay"] <= pd.Timedelta(days=2*365)]

df["realtime_dates"] = df.apply(lambda x: pd.date_range(x.realtime_start, x.realtime_end, freq="D"), axis=1)
# Out:
# C:\Users\mushj\AppData\Local\Temp\ipykernel_14840\531676782.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["realtime_dates"] = df.apply(lambda x: pd.date_range(x.realtime_start, x.realtime_end, freq="D"), axis=1)

# %%
df2 = (df
       .explode("realtime_dates")
       .sort_values(["realtime_dates", "date"])
      )

# %%
df2.head(30)
# Out:
#    realtime_start realtime_end       date   WEI release_delay realtime_dates
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-05
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-06
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-07
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-08
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-09
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-10
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-11
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-12
# 11     2008-01-12   2020-06-08 2008-01-12  1.42        0 days     2008-01-12
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-13
# 11     2008-01-12   2020-06-08 2008-01-12  1.42        0 days     2008-01-13
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-14
# 11     2008-01-12   2020-06-08 2008-01-12  1.42        0 days     2008-01-14
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-15
# 11     2008-01-12   2020-06-08 2008-01-12  1.42        0 days     2008-01-15
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-16
# 11     2008-01-12   2020-06-08 2008-01-12  1.42        0 days     2008-01-16
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-17
# 11     2008-01-12   2020-06-08 2008-01-12  1.42        0 days     2008-01-17
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-18
# 11     2008-01-12   2020-06-08 2008-01-12  1.42        0 days     2008-01-18
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-19
# 11     2008-01-12   2020-06-08 2008-01-12  1.42        0 days     2008-01-19
# 21     2008-01-19   2020-06-08 2008-01-19  1.42        0 days     2008-01-19
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-20
# 11     2008-01-12   2020-06-08 2008-01-12  1.42        0 days     2008-01-20
# 21     2008-01-19   2020-06-08 2008-01-19  1.42        0 days     2008-01-20
# 0      2008-01-05   2020-06-08 2008-01-05  1.48        0 days     2008-01-21
# 11     2008-01-12   2020-06-08 2008-01-12  1.42        0 days     2008-01-21
# 21     2008-01-19   2020-06-08 2008-01-19  1.42        0 days     2008-01-21

# %%
# example:
# the table lists potential historical values of an external variable to use
# for predicting a target variable on the day 2023-04-30
df2.query("realtime_dates == '2023-04-30'")
# Out:
#      realtime_start realtime_end       date   WEI realtime_dates
# 7        2022-10-06   2023-05-17 2008-01-05  1.68     2023-04-30
# 18       2022-10-06   2023-06-21 2008-01-12  1.63     2023-04-30
# 27       2022-10-06   2023-05-17 2008-01-19  1.60     2023-04-30
# 38       2022-10-06   2023-06-21 2008-01-26  1.10     2023-04-30
# 47       2022-10-06   2023-05-17 2008-02-02  0.79     2023-04-30
# ...             ...          ...        ...   ...            ...
# 7674     2023-04-13   2023-05-17 2023-03-25  1.45     2023-04-30
# 7678     2023-04-13   2023-05-17 2023-04-01  1.59     2023-04-30
# 7682     2023-04-20   2023-05-17 2023-04-08  0.97     2023-04-30
# 7687     2023-04-27   2023-05-17 2023-04-15  0.79     2023-04-30
# 7690     2023-04-27   2023-05-03 2023-04-22  1.13     2023-04-30
#
# [799 rows x 5 columns]

# %%
# for each date to predict,
# pick a historical value of the predictor to use
df3 = (df2
 .groupby("realtime_dates")
 .agg({"date": lambda x: x.tail(1), series_id: lambda x: x.tail(1)})
)

df3
# Out:
#                      date    WEI
# realtime_dates
# 2020-04-16     2020-04-11 -11.04
# 2020-04-17     2020-04-11 -11.04
# 2020-04-18     2020-04-11 -11.04
# 2020-04-19     2020-04-11 -11.04
# 2020-04-20     2020-04-11 -11.04
# ...                   ...    ...
# 2023-12-27     2023-10-14   2.27
# 2023-12-28     2023-10-14   2.27
# 2023-12-29     2023-10-14   2.27
# 2023-12-30     2023-10-14   2.27
# 2023-12-31     2023-10-14   2.27
#
# [1355 rows x 2 columns]

# %%
df3.resample("MS")[series_id].mean()
# Out:
# realtime_dates
# 2020-04-01   -11.357333
# 2020-05-01   -11.250968
# 2020-06-01    -9.315667
# 2020-07-01    -7.013548
# 2020-08-01    -5.840968
# 2020-09-01    -4.694000
# 2020-10-01    -4.059032
# 2020-11-01    -2.926000
# 2020-12-01    -2.339032
# 2021-01-01    -1.814194
# 2021-02-01    -2.426071
# 2021-03-01    -0.210645
# 2021-04-01    10.292000
# 2021-05-01    11.650000
# 2021-06-01    10.334333
# 2021-07-01     9.160323
# 2021-08-01     7.901613
# 2021-09-01     7.764667
# 2021-10-01     7.510000
# 2021-11-01     6.925333
# 2021-12-01     7.533548
# 2022-01-01     6.275484
# 2022-02-01     5.738929
# 2022-03-01     5.390323
# 2022-04-01     4.543000
# 2022-05-01     4.091613
# 2022-06-01     3.357000
# 2022-07-01     2.862581
# 2022-08-01     2.996129
# 2022-09-01     2.554000
# 2022-10-01     2.137097
# 2022-11-01     1.920333
# 2022-12-01     1.153548
# 2023-01-01     1.203548
# 2023-02-01     0.998929
# 2023-03-01     1.006129
# 2023-04-01     1.308000
# 2023-05-01     0.994516
# 2023-06-01     1.026000
# 2023-07-01     1.352258
# 2023-08-01     1.522258
# 2023-09-01     1.941333
# 2023-10-01     2.088387
# 2023-11-01     2.270000
# 2023-12-01     2.270000
# Freq: MS, Name: WEI, dtype: float64

# %% [markdown]
# ## check_nans()

# %%
def check_nans(df, subset):
    """
    """
    nans = df[subset].isna().sum()
    
    if all(nans == 0):
        return False, False
    else:
        return True, nans

# %%
check_nans(df, ["date", series_id])

# %% [markdown]
# ## change_frequency()

# %%
def change_frequency(df, data_freq, target_freq):
    """Downsample / upsample the data to match the target
    frequency.
    """
    # increasing order of frequency
    freq_order = ["Q", "M", "W", "D"]
    data_freq_order = freq_order.index(data_freq[0])
    target_freq_order = freq_order.index(target_freq[0])
    
    # down- or up-sampling
    if data_freq_order < target_freq_order:
        upsample = True
    elif data_freq_order > target_freq_order:
        upsample = False
    else:
        return df
    
    # check if periods are labelled with the left or right edge
    if "S" in data_freq:
        left_label = True
    else:
        left_label = False

# %%
filenames = os.listdir("../Database")

# %%
df = pd.read_csv(f"../Database/{filenames[-1]}")

# %%
df
# Out:
#       Unnamed: 0        Date  YIELD  2 MO  3 MO  6 MO  1 YR  2 YR  3 YR  5 YR  \
# 0              0  1990-01-02    NaN   NaN  7.83  7.89  7.81  7.87  7.90  7.87
# 1              1  1990-01-03    NaN   NaN  7.89  7.94  7.85  7.94  7.96  7.92
# 2              2  1990-01-04    NaN   NaN  7.84  7.90  7.82  7.92  7.93  7.91
# 3              3  1990-01-05    NaN   NaN  7.79  7.85  7.79  7.90  7.94  7.92
# 4              4  1990-01-08    NaN   NaN  7.79  7.88  7.81  7.90  7.95  7.92
# ...          ...         ...    ...   ...   ...   ...   ...   ...   ...   ...
# 8454        8454  2023-10-16   5.57  5.58  5.61  5.58  5.42  5.09  4.87  4.72
# 8455        8455  2023-10-17   5.58  5.58  5.62  5.60  5.48  5.19  5.01  4.86
# 8456        8456  2023-10-18   5.57  5.56  5.61  5.58  5.47  5.19  5.03  4.92
# 8457        8457  2023-10-19   5.58  5.57  5.60  5.56  5.44  5.14  5.01  4.95
# 8458        8458  2023-10-20   5.56  5.56  5.58  5.54  5.41  5.07  4.93  4.86
#
#       7 YR  10 YR  20 YR  30 YR
# 0     7.98   7.94    NaN   8.00
# 1     8.04   7.99    NaN   8.04
# 2     8.02   7.98    NaN   8.04
# 3     8.03   7.99    NaN   8.06
# 4     8.05   8.02    NaN   8.09
# ...    ...    ...    ...    ...
# 8454  4.74   4.71   5.06   4.87
# 8455  4.88   4.83   5.14   4.94
# 8456  4.95   4.91   5.20   5.00
# 8457  5.00   4.98   5.30   5.11
# 8458  4.93   4.93   5.27   5.09
#
# [8459 rows x 14 columns]
